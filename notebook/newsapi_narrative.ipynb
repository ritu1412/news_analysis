# %%
from eventregistry import *
import json, os, sys
import pandas as pd
import numpy as np
from openai import OpenAI

# %%
api_key = os.getenv("NEWSAPI_API_KEY")
event_registry = EventRegistry(apiKey=api_key, allowUseOfArchive=False)
openai_client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# %%
search_query = "Joe Biden"
event_query = QueryEventsIter(keywords=search_query)
event_list =[]
for event in event_query.execQuery(event_registry, sortBy="size", maxItems=1):
    print(json.dumps(event, indent=4))
    #event_list.append(event)
# Out:
# {
#     "uri": "spa-3486596",
#     "concepts": [
#         {
#             "uri": "http://en.wikipedia.org/wiki/Iran",
#             "type": "loc",
#             "score": 100,
#             "label": {
#                 "eng": "Iran"
#             },
#             "location": {
#                 "type": "country",
#                 "label": {
#                     "eng": "Iran"
#                 }
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Helicopter",
#             "type": "wiki",
#             "score": 69,
#             "label": {
#                 "eng": "Helicopter"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/President_of_Iran",
#             "type": "wiki",
#             "score": 58,
#             "label": {
#                 "eng": "President of Iran"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Azerbaijan",
#             "type": "loc",
#             "score": 32,
#             "label": {
#                 "eng": "Azerbaijan"
#             },
#             "location": {
#                 "type": "country",
#                 "label": {
#                     "eng": "Azerbaijan"
#                 }
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Ali_Khamenei",
#             "type": "person",
#             "score": 29,
#             "label": {
#                 "eng": "Ali Khamenei"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Tehran",
#             "type": "loc",
#             "score": 26,
#             "label": {
#                 "eng": "Tehran"
#             },
#             "location": {
#                 "type": "place",
#                 "label": {
#                     "eng": "Tehran"
#                 },
#                 "country": {
#                     "type": "country",
#                     "label": {
#                         "eng": "Iran"
#                     }
#                 }
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/East_Azerbaijan_Province",
#             "type": "loc",
#             "score": 25,
#             "label": {
#                 "eng": "East Azerbaijan Province"
#             },
#             "location": {
#                 "type": "place",
#                 "label": {
#                     "eng": "East Azerbaijan Province"
#                 },
#                 "country": {
#                     "type": "country",
#                     "label": {
#                         "eng": "Iran"
#                     }
#                 }
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Foreign_minister",
#             "type": "wiki",
#             "score": 25,
#             "label": {
#                 "eng": "Foreign minister"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/President_(government_title)",
#             "type": "wiki",
#             "score": 21,
#             "label": {
#                 "eng": "President (government title)"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Israel",
#             "type": "loc",
#             "score": 19,
#             "label": {
#                 "eng": "Israel"
#             },
#             "location": {
#                 "type": "country",
#                 "label": {
#                     "eng": "Israel"
#                 }
#             }
#         },
#         {
#             "uri": "http://es.wikipedia.org/wiki/Ebrahim_Raisi",
#             "type": "wiki",
#             "score": 18,
#             "label": {
#                 "eng": "Ebrahim Raisi"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Tabriz",
#             "type": "loc",
#             "score": 17,
#             "label": {
#                 "eng": "Tabriz"
#             },
#             "location": {
#                 "type": "place",
#                 "label": {
#                     "eng": "Tabriz"
#                 },
#                 "country": {
#                     "type": "country",
#                     "label": {
#                         "eng": "Iran"
#                     }
#                 }
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Supreme_Leader_of_Iran",
#             "type": "wiki",
#             "score": 16,
#             "label": {
#                 "eng": "Supreme Leader of Iran"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Russia",
#             "type": "loc",
#             "score": 14,
#             "label": {
#                 "eng": "Russia"
#             },
#             "location": {
#                 "type": "country",
#                 "label": {
#                     "eng": "Russia"
#                 }
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Ayatollah",
#             "type": "wiki",
#             "score": 13,
#             "label": {
#                 "eng": "Ayatollah"
#             }
#         },
#         {
#             "uri": "http://de.wikipedia.org/wiki/Ebrahim_Raisi",
#             "type": "wiki",
#             "score": 12,
#             "label": {
#                 "eng": "Ebrahim Raisi"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Islamic_Republic_News_Agency",
#             "type": "org",
#             "score": 12,
#             "label": {
#                 "eng": "Islamic Republic News Agency"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Turkey",
#             "type": "loc",
#             "score": 12,
#             "label": {
#                 "eng": "Turkey"
#             },
#             "location": {
#                 "type": "country",
#                 "label": {
#                     "eng": "Turkey"
#                 }
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Ilham_Aliyev",
#             "type": "person",
#             "score": 11,
#             "label": {
#                 "eng": "Ilham Aliyev"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Governor",
#             "type": "wiki",
#             "score": 11,
#             "label": {
#                 "eng": "Governor"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Unmanned_aerial_vehicle",
#             "type": "wiki",
#             "score": 10,
#             "label": {
#                 "eng": "Unmanned aerial vehicle"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/President_of_the_Republic",
#             "type": "wiki",
#             "score": 8,
#             "label": {
#                 "eng": "President of the Republic"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Constitution",
#             "type": "wiki",
#             "score": 8,
#             "label": {
#                 "eng": "Constitution"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/International_Red_Cross_and_Red_Crescent_Movement",
#             "type": "wiki",
#             "score": 8,
#             "label": {
#                 "eng": "International Red Cross and Red Crescent Movement"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/United_States",
#             "type": "loc",
#             "score": 8,
#             "label": {
#                 "eng": "United States"
#             },
#             "location": {
#                 "type": "country",
#                 "label": {
#                     "eng": "United States"
#                 }
#             }
#         },
#         {
#             "uri": "http://it.wikipedia.org/wiki/Ebrahim_Raisi",
#             "type": "wiki",
#             "score": 7,
#             "label": {
#                 "eng": "Ebrahim Raisi"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Abdullah_of_Saudi_Arabia",
#             "type": "person",
#             "score": 7,
#             "label": {
#                 "eng": "Abdullah of Saudi Arabia"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Iranian_Revolution",
#             "type": "wiki",
#             "score": 7,
#             "label": {
#                 "eng": "Iranian Revolution"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Vice_president",
#             "type": "wiki",
#             "score": 7,
#             "label": {
#                 "eng": "Vice president"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Vice_President_of_the_United_States",
#             "type": "wiki",
#             "score": 7,
#             "label": {
#                 "eng": "Vice President of the United States"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Middle_East",
#             "type": "loc",
#             "score": 7,
#             "label": {
#                 "eng": "Middle East"
#             },
#             "location": null
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Television",
#             "type": "wiki",
#             "score": 7,
#             "label": {
#                 "eng": "Television"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Mashhad",
#             "type": "loc",
#             "score": 7,
#             "label": {
#                 "eng": "Mashhad"
#             },
#             "location": {
#                 "type": "place",
#                 "label": {
#                     "eng": "Mashhad"
#                 },
#                 "country": {
#                     "type": "country",
#                     "label": {
#                         "eng": "Iran"
#                     }
#                 }
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Islamic_Revolutionary_Guard_Corps",
#             "type": "wiki",
#             "score": 6,
#             "label": {
#                 "eng": "Islamic Revolutionary Guard Corps"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/President_of_Azerbaijan",
#             "type": "wiki",
#             "score": 6,
#             "label": {
#                 "eng": "President of Azerbaijan"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Hamas",
#             "type": "org",
#             "score": 6,
#             "label": {
#                 "eng": "Hamas"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Hassan_Rouhani",
#             "type": "person",
#             "score": 5,
#             "label": {
#                 "eng": "Hassan Rouhani"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Muhammad",
#             "type": "person",
#             "score": 5,
#             "label": {
#                 "eng": "Muhammad"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Vladimir_Putin",
#             "type": "person",
#             "score": 5,
#             "label": {
#                 "eng": "Vladimir Putin"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Denmark",
#             "type": "loc",
#             "score": 5,
#             "label": {
#                 "eng": "Denmark"
#             },
#             "location": {
#                 "type": "country",
#                 "label": {
#                     "eng": "Denmark"
#                 }
#             }
#         }
#     ],
#     "eventDate": "2024-05-19",
#     "totalArticleCount": 5310,
#     "title": {
#         "spa": "Presidente de Ir\u00e1n muere en accidente de helic\u00f3ptero y de eso hablan las redes sociales",
#         "zho": "\u4f0a\u6717\u7e3d\u7d71\u76f4\u5347\u6a5f\u6fc3\u9727\u4e2d\u589c\u5c71\u5340 \u51fa\u52d5\u903e40\u7d44\u4eba\u99ac\u641c\u7d22",
#         "rus": "\u0421\u041c\u0418: \u0441\u043f\u0430\u0441\u0430\u0442\u0435\u043b\u0438 \u043d\u0430\u0448\u043b\u0438 \u0432\u0435\u0440\u0442\u043e\u043b\u0435\u0442 \u0420\u0430\u0438\u0441\u0438",
#         "deu": "Iran-Pr\u00e4sident Raisi: Retter sollen Kontakt zu Heli-Insassen haben",
#         "ita": "IRAN: Leader supremo approva Mokhber come presidente ad interim, dichiara 5 giorni lutto Da Reuters",
#         "tur": "\u0130ran Cumhurba\u015fkan\u0131 \u0130brahim Reisi kim? - BBC News T\u00fcrk\u00e7e",
#         "fra": "Iran : les principales r\u00e9actions apr\u00e8s la mort du pr\u00e9sident Ebrahim Ra\u00efssi",
#         "ukr": "\u0406\u0440\u0430\u043d\u0441\u044c\u043a\u0456 \u0417\u041c\u0406 \u0437\u0430\u044f\u0432\u0438\u043b\u0438 \u043f\u0440\u043e \u0437\u0430\u0433\u0438\u0431\u0435\u043b\u044c \u043f\u0440\u0435\u0437\u0438\u0434\u0435\u043d\u0442\u0430 \u0420\u0430\u0457\u0441\u0456",
#         "cat": "Iran confirma la mort del president i del ministre d'Exteriors en...",
#         "eng": "Iranian president's death 'loss to people aspiring justice,' says North Korea's Kim",
#         "srp": "\u041c\u0435\u0445\u0440: \u0418\u0440\u0430\u043d\u0441\u043a\u0438 \u043f\u0440\u0435\u0434\u0441\u0435\u0434\u043d\u0438\u043a \u0438 \u0448\u0435\u0444 \u0434\u0438\u043f\u043b\u043e\u043c\u0430\u0442\u0438\u0458\u0435 \u043f\u043e\u0433\u0438\u043d\u0443\u043b\u0438",
#         "slv": "Je Iran izgubil predsednika v helikopterski nesre\u010di? | Nova24TV"
#     },
#     "summary": {
#         "spa": "Asumir\u00e1 un l\u00edder interino y se celebrar\u00e1n elecciones en un plazo m\u00e1ximo de 50 d\u00edas.\n\nEl presidente de Ir\u00e1n, Ebrahim Raisi, falleci\u00f3 en un accidente de helic\u00f3ptero, conmocionando a la naci\u00f3n y generando incertidumbre en un momento de tensiones crecientes en Medio Oriente.\n\n\"La naci\u00f3n iran\u00ed ha perdido a un servidor sincero, devoto y valioso\", declar\u00f3 el l\u00edder supremo de Ir\u00e1n, el ayatol\u00e1 Ali Jamenei, en un comunicado emitido este lunes 20 de mayo al anunciar cinco d\u00edas de duelo nacio",
#         "zho": "\uff08\u6cd5\u65b0\u793e\u5fb7\u9ed1\u862d19\u65e5\u96fb\uff09 \u5b98\u65b9\u5a92\u9ad4\u5831\u5c0e\uff0c\u642d\u8f09\u4f0a\u6717\u7e3d\u7d71\u840a\u5e0c\uff08Ebrahim Raisi\uff09\u7684\u76f4\u5347\u6a5f\u906d\u9047\u60e1\u52a3\u5929\u6c23\uff0c\u5728\u897f\u5317\u90e8\u5c71\u5340\u767c\u751f\u610f\u5916\u4e8b\u6545\uff0c\u840a\u5e0c\u547d\u904b\u672a\u535c\u3002\n\n\u4f0a\u6717\u5728\u6771\u4e9e\u585e\u62dc\u7136\u7701\uff08East Azerbaijan\uff09\u6fc3\u9727\u7c60\u7f69\u7684\u5c71\u5340\u5c55\u958b\u5927\u898f\u6a21\u641c\u6551\u884c\u52d5\u3002\u4f0a\u6717\u6700\u9ad8\u9818\u8896\u54c8\u7c73\u5c3c\uff08Ali Khamenei\uff09\u6566\u4fc3\u6c11\u773e\u300c\u7121\u9700\u70ba\u570b\u5bb6\u64d4\u5fc3\u300d\uff0c\u4e26\u5e0c\u671b\u840a\u5e0c\u548c\u540c\u884c\u4eba\u54e1\u5b89\u7136\u7121\u6059\u3002\n\n\u4f0a\u6717\u570b\u71df\u96fb\u8996\u53f0\u4eca\u5929\u5831\u5c0e\uff0c\u642d\u8f09\u840a\u5e0c\u7684\u76f4\u5347\u6a5f\u906d\u9047\u60e1\u52a3\u5929",
#         "rus": "\u0412\u0435\u0440\u0442\u043e\u043b\u0435\u0442 \u043f\u0440\u0435\u0437\u0438\u0434\u0435\u043d\u0442\u0430 \u0418\u0440\u0430\u043d\u0430 \u042d\u0431\u0440\u0430\u0445\u0438\u043c\u0430 \u0420\u0430\u0438\u0441\u0438 \u043d\u0430\u0448\u043b\u0438. \u041e\u0431 \u044d\u0442\u043e\u043c \u043f\u0438\u0448\u0435\u0442 \u0422\u0410\u0421\u0421.\n\n\u041f\u043e\u0434\u0440\u043e\u0431\u043d\u043e\u0441\u0442\u0438 \u043e \u0441\u043e\u0441\u0442\u043e\u044f\u043d\u0438\u0438 \u043f\u0430\u0441\u0441\u0430\u0436\u0438\u0440\u043e\u0432 \u043f\u043e\u043a\u0430 \u043e\u0441\u0442\u0430\u044e\u0442\u0441\u044f \u043d\u0435\u0438\u0437\u0432\u0435\u0441\u0442\u043d\u044b\u043c\u0438.\n\n\u0414\u043e \u044d\u0442\u043e\u0433\u043e \u0434\u0432\u0430 \u043f\u0430\u0441\u0441\u0430\u0436\u0438\u0440\u0430 \u0441\u0430\u043c\u043e\u043b\u0435\u0442\u0430 \u043f\u0440\u0435\u0437\u0438\u0434\u0435\u043d\u0442\u0430 \u0418\u0440\u0430\u043d\u0430 \u0420\u0430\u043c\u0441\u0438 \u0432\u044b\u0448\u043b\u0438 \u043d\u0430 \u0441\u0432\u044f\u0437\u044c.\n\n19 \u043c\u0430\u044f \u0432\u0435\u0440\u0442\u043e\u043b\u0435\u0442 \u0441 \u043f\u0440\u0435\u0437\u0438\u0434\u0435\u043d\u0442\u043e\u043c \u0418\u0440\u0430\u043d\u0430 \u0441\u043e\u0432\u0435\u0440\u0448\u0438\u043b \u0436\u0435\u0441\u0442\u043a\u0443\u044e \u043f\u043e\u0441\u0430\u0434\u043a\u0443. \u041d\u0430 \u0431\u043e\u0440\u0442",
#         "deu": "Noch immer fehlt von ihm jede Spur: Iran-Pr\u00e4sident Ebrahim Raisi (63) soll am Sonntag mit einem Hubschrauber verungl\u00fcckt sein. Das meldete das iranische Staatsfernsehen, andere Medien sprachen zun\u00e4chst nur von einem \"Vorfall mit dem Hubschrauber, der den Pr\u00e4sidenten transportierte\".\n\nRaisis Schicksal und das der acht weiteren Insassen des Hubschraubers ist aktuell noch v\u00f6llig unklar. An Bord sollen auch Iran-Au\u00dfenminister Hossein Amir-Abdollahian und der Gouverneur der Region Ost-Aserbaidsc",
#         "ita": "(Reuters) - Il presidente iraniano Ebrahim Raisi \u00e8 rimasto ucciso in un incidente in elicottero.\n\nDi seguito gli aggiornamenti:\n\n10,15 - La Guida suprema iraniana Ali Khamenei ha annunciato che il primo vice presidente Mohammad Mokhber \u00e8 ora responsabile del ramo esecutivo e ha un periodo massimo di 50 giorni per indire le elezioni in seguito alla morte di Raisi, secondo quanto riferito dall'agenzia di stampa ufficiale iraniana Irna.\n\nKhamenei ha proclamato cinque giorni di lutto nazionale.\n\n9,",
#         "tur": "\u0130ran'da \u0130brahim Reisi ve beraberindekilerin yer ald\u0131\u011f\u0131 helikopter konvoyunu arama \u00e7al\u0131\u015fmalar\u0131 s\u00fcr\u00fcyor.\n\n\u0130slam Cumhuriyeti'nin son cumhurba\u015fkan\u0131 Reisi 2021'de g\u00f6reve geldi.\n\nRejime s\u0131k\u0131 s\u0131k\u0131ya ba\u011fl\u0131 bir isim olan Reisi, 2017'de cumhurba\u015fkanl\u0131\u011f\u0131 se\u00e7imlerini rakibi Hasan Ruhani kar\u015f\u0131s\u0131nda kaybetti.\n\n63 ya\u015f\u0131ndaki Reisi, dini lider Ali Hamaney'in halefi olarak g\u00f6r\u00fcl\u00fcyor.\n\nRejime s\u0131k\u0131 ba\u011fl\u0131l\u0131\u011f\u0131yla bilinen din adam\u0131, \u0130ran'\u0131n dini a\u00e7\u0131dan \u00f6nemli \u015fehirlerinde",
#         "fra": "De nombreux dirigeants ont r\u00e9agi apr\u00e8s l'annonce de la mort du pr\u00e9sident iranien. Le d\u00e9c\u00e8s d'Ebrahim Ra\u00efssi a \u00e9t\u00e9 confirm\u00e9 lundi matin au lendemain d'un accident d'h\u00e9licopt\u00e8re, avec huit personnes \u00e0 bord. Le gouvernement iranien a d\u00e9clar\u00e9 cinq jours de deuil national pour rendre hommage \u00e0 celui qui \" a sacrifi\u00e9 sa vie pour la nation \".\n\nUne journ\u00e9e de deuil va \u00e9galement \u00eatre observ\u00e9e au Pakistan o\u00f9 \" le drapeau sera en berne \" en \" solidarit\u00e9 avec l'Iran \", pays \" fr\u00e8re \", ",
#         "ukr": "\u0406\u0440\u0430\u043d\u0441\u044c\u043a\u0456 \u0417\u041c\u0406 \u043e\u0433\u043e\u043b\u043e\u0441\u0438\u043b\u0438 \u043f\u0440\u0435\u0437\u0438\u0434\u0435\u043d\u0442\u0430 \u0406\u0431\u0440\u0430\u0433\u0456\u043c\u0430 \u0420\u0430\u0457\u0441\u0456 \u043c\u0435\u0440\u0442\u0432\u0438\u043c, \u043f\u0456\u0441\u043b\u044f \u0442\u043e\u0433\u043e, \u044f\u043a \u0439\u043e\u0433\u043e \u0433\u0435\u043b\u0456\u043a\u043e\u043f\u0442\u0435\u0440 \u0440\u043e\u0437\u0431\u0438\u0432\u0441\u044f \u0432 \u0433\u0456\u0440\u0441\u044c\u043a\u043e\u043c\u0443 \u043f\u0456\u0432\u043d\u0456\u0447\u043d\u043e-\u0437\u0430\u0445\u0456\u0434\u043d\u043e\u043c\u0443 \u0440\u0435\u0433\u0456\u043e\u043d\u0456 \u043a\u0440\u0430\u0457\u043d\u0438, \u0445\u043e\u0447\u0430 \u043e\u0444\u0456\u0446\u0456\u0439\u043d\u043e\u0433\u043e \u043f\u0456\u0434\u0442\u0432\u0435\u0440\u0434\u0436\u0435\u043d\u043d\u044f \u0446\u044c\u043e\u0433\u043e \u043f\u043e\u043a\u0438 \u0449\u043e \u043d\u0435\u043c\u0430\u0454. \u041f\u043e\u0448\u0443\u043a\u0438 \u0442\u0440\u0438\u0432\u0430\u044e\u0442\u044c.\n\n\u0406\u0440\u0430\u043d\u0441\u044c\u043a\u0456 \u0417\u041c\u0406 \u043e\u0433\u043e\u043b\u043e\u0441\u0438\u043b\u0438 \u043f\u0440\u0435\u0437\u0438\u0434\u0435\u043d\u0442\u0430 \u0406\u0431\u0440\u0430\u0433\u0456\u043c\u0430 \u0420\u0430\u0457\u0441\u0456 \u043c\u0435\u0440\u0442\u0432\u0438\u043c ",
#         "cat": "El Govern irani\u00e0 anuncia una reuni\u00f3 urgent de gabinet\n\nMADRID, 20 May. (EUROPA PRESS TELEVISI\u00d3) -\n\nEl Govern d'Iran ha confirmat la mort del president del pa\u00eds, Ebrahim Raisi, del ministre d'Exteriors, Hosein Amirabdolahia, i de la resta d'acompanyants en l'accident d'helic\u00f2pter patit durant la vesprada del diumenge en una zona muntanyenca i de dif\u00edcil acc\u00e9s de la prov\u00edncia d'Azerbaidjan Oriental, en l'extrem nord d'Iran.\n\n\"L'aiatol\u00b7l\u00e0 Ebrahim Raisi, president de la Rep\u00fablica Isl\u00e0mica",
#         "eng": "Kim Jong-un says deceased Ebrahim Raisi was 'outstanding statesman and a close friend' of North Korean people\n\nNorth Korean leader Kim Jong-un Tuesday said the death of Iranian President Ebrahim Raisi was a \"loss to people aspiring justice,\" state media reported.\n\nIn a condolence message to Mohammad Mokhber, Iran's first vice president, Kim said: \"The demise of the president is a great loss to the fraternal Iranian people and the world people aspiring after independence and justice.\"\n\nRaisi \"was ",
#         "srp": "\u0418\u0440\u0430\u043d\u0441\u043a\u0438 \u043f\u0440\u0435\u0434\u0441\u0435\u0434\u043d\u0438\u043a \u0415\u0431\u0440\u0430\u0445\u0438\u043c \u0420\u0430\u0438\u0441\u0438 \u0438 \u043c\u0438\u043d\u0438\u0441\u0442\u0430\u0440 \u0441\u043f\u043e\u0459\u043d\u0438\u0445 \u043f\u043e\u0441\u043b\u043e\u0432\u0430 \u0425\u043e\u0441\u0435\u0438\u043d \u0410\u043c\u0438\u0440 \u0410\u0431\u0434\u043e\u043b\u0430\u0445\u0438\u0458\u0430\u043d \u043f\u043e\u0433\u0438\u043d\u0443\u043b\u0438 \u0441\u0443 \u043a\u0430\u0434\u0430 \u0441\u0435 \u045a\u0438\u0445\u043e\u0432 \u0445\u0435\u043b\u0438\u043a\u043e\u043f\u0442\u0435\u0440 \u0441\u0440\u0443\u0448\u0438\u043e \u0434\u043e\u043a \u0458\u0435 \u043f\u0440\u0435\u043b\u0430\u0437\u0438\u043e \u0438\u0437\u043d\u0430\u0434 \u043f\u043b\u0430\u043d\u0438\u043d\u0441\u043a\u043e\u0433 \u0442\u0435\u0440\u0435\u043d\u0430 \u0443 \u0458\u0430\u043a\u043e\u0458 \u043c\u0430\u0433\u043b\u0438, \u0458\u0430\u0432\u0438\u043b\u0430 \u0458\u0435 \u0458\u0443\u0442\u0440\u043e\u0441 \u0438\u0440\u0430\u043d\u0441\u043a\u0430 \u043d\u043e\u0432\u0438\u043d\u0441\u043a\u0430 \u0430\u0433\u0435\u043d\u0446\u0438\u0458\u0430.\n\n\u0418\u0440\u0430\u043d\u0441\u043a\u0438 \u043f\u0440\u0435\u0434\u0441\u0435\u0434\u043d\u0438\u043a \u0415\u0431\u0440\u0430\u0445\u0438\u043c \u0420\u0430\u0438\u0441\u0438 \u0438 \u043c\u0438\u043d\u0438\u0441\u0442\u0430\u0440",
#         "slv": "V iranski provinci Vzhodni Azerbajd\u017ean je strmoglavil helikopter, na katerem so bili iranski predsednik Ebrahim Raisi, zunanji minister Hosein Amir-Abdolahian in guverner Vzhodnega Azerbajd\u017eana Malek Rahmati. Natan\u010dnih podatkov o usodah omenjenih \u0161e ni.\n\nPo do zdaj znanih podatkih se je helikopter z Raisijem na krovu na poti iz Azerbajd\u017eana zna\u0161el v te\u017eavah. Nekateri mediji so poro\u010dali o \"trdem pristanku\" na goratem obmo\u010dju med mestoma D\u017eolfa in Varzakan v iranski provinci Vzhodni Azerb"
#     },
#     "location": {
#         "type": "place",
#         "label": {
#             "eng": "Tehran"
#         },
#         "country": {
#             "type": "country",
#             "label": {
#                 "eng": "Iran"
#             }
#         }
#     },
#     "categories": [
#         {
#             "uri": "dmoz/Society/Religion_and_Spirituality/Zoroastrianism",
#             "label": "dmoz/Society/Religion and Spirituality/Zoroastrianism",
#             "wgt": 100
#         },
#         {
#             "uri": "dmoz/Sports/Martial_Arts/Korean",
#             "label": "dmoz/Sports/Martial Arts/Korean",
#             "wgt": 100
#         },
#         {
#             "uri": "news/Politics",
#             "label": "news/Politics",
#             "wgt": 90
#         }
#     ],
#     "articleCounts": {
#         "spa": 1239,
#         "zho": 1708,
#         "rus": 790,
#         "deu": 377,
#         "ita": 397,
#         "tur": 338,
#         "fra": 195,
#         "ukr": 199,
#         "cat": 33,
#         "eng": 10,
#         "srp": 13,
#         "slv": 11
#     },
#     "sentiment": -0.1529411764705882,
#     "wgt": 5310,
#     "relevance": 26
# }

# %%
event_uri = event["uri"]
lang = "zho"
q = QueryEventArticlesIter(eventUri=event_uri, lang=lang)
filename = "../data/processed/" + lang + "_" + event_uri + ".json"
if os.path.exists(filename):
    os.remove(filename)
articles = []
for article in q.execQuery(
    event_registry,
    sortBy="date",
    maxItems=10,
    returnInfo=ReturnInfo(sourceInfo=SourceInfoFlags(location=True),),
    ):
    articles.append(article)

with open(filename, "w") as f:
    json.dump(articles, f, ensure_ascii=False, indent=4)

# %%
lang = "eng"
q = QueryEventArticlesIter(eventUri=event_uri, lang=lang)
filename = "../data/processed/" + lang + "_" + event_uri + ".json"
if os.path.exists(filename):
    os.remove(filename)
articles = []
for article in q.execQuery(
    event_registry,
    sortBy="date",
    maxItems=10,
    returnInfo=ReturnInfo(sourceInfo=SourceInfoFlags(location=True),),
    ):
    articles.append(article)

with open(filename, "w") as f:
    json.dump(articles, f, ensure_ascii=False, indent=4)

# %%
def openai_distinctive_events_list(
    article,
    openai_client,
    model="gpt-4o",
):

    prompt_complete = (
        f"You are an expert at summarizing the news. \
            Read the following news article and translate it into English if necessary. \
                 Create a list of distinctive events described in the article, arranged in chronological order. The first event listed should be the earliest event mentioned in the article, followed by the subsequent events in the order they occurred: "
        + article["body"]
    )
    model = model
    messages = [{"role": "user", "content": prompt_complete}]
    try:
        response = openai_client.chat.completions.create(
            model=model, messages=messages, temperature=0
        )

        content = response.choices[0].message.content
        return content
    except Exception as e:  # if the model fails to return a response
        print(f"Error: {e}")
        return "Sorry, error from GPT."

# %%
src_filename = "../data/processed/" + lang + "_" + event_uri + ".json"
with open(src_filename, "r") as f:
    data = f.read()
    des_articles = []
    src_articles = json.loads(data)
    for src_art in src_articles:
        src_art["distinctive_events"] = openai_distinctive_events_list(
            src_art, openai_client, model="gpt-4o"
        )

        des_articles.append(src_art)

des_filename = src_filename + "_distinctive_events.json"
if os.path.exists(des_filename):
    os.remove(des_filename)
with open(des_filename, "w") as f:
    json.dump(des_articles, f, indent=4)

# %%
lang = "zho"
src_filename = "../data/processed/" + lang + "_" + event_uri + ".json"
with open(src_filename, "r") as f:
    data = f.read()
    des_articles = []
    src_articles = json.loads(data)
    for src_art in src_articles:
        src_art["distinctive_events"] = openai_distinctive_events_list(
            src_art, openai_client, model="gpt-4o"
        )

        des_articles.append(src_art)

des_filename = src_filename + "_distinctive_events.json"
if os.path.exists(des_filename):
    os.remove(des_filename)
with open(des_filename, "w") as f:
    json.dump(des_articles, f, indent=4)

# %%
lang = "zho"
src_filename = "../data/processed/" + lang + "_" + event_uri + ".json"
with open(src_filename, "r") as f:
    data = f.read()
    des_articles = []
    src_articles = json.loads(data)
    for src_art in src_articles:
        src_art["distinctive_events"] = openai_distinctive_events_list(
            src_art, openai_client, model="gpt-4o"
        )

        des_articles.append(src_art)

des_filename = src_filename + "_distinctive_events.json"
if os.path.exists(des_filename):
    os.remove(des_filename)
with open(des_filename, "w") as f:
    json.dump(des_articles, f, indent=4)

# %%
lang = "hin"
src_filename = "../data/processed/" + lang + "_" + "hin-359877" + ".json"
with open(src_filename, "r") as f:
    data = f.read()
    des_articles = []
    src_articles = json.loads(data)
    for src_art in src_articles:
        src_art["distinctive_events"] = openai_distinctive_events_list(
            src_art, openai_client, model="gpt-4o"
        )

        des_articles.append(src_art)

des_filename = src_filename + "_distinctive_events.json"
if os.path.exists(des_filename):
    os.remove(des_filename)
with open(des_filename, "w") as f:
    json.dump(des_articles, f, indent=4)
