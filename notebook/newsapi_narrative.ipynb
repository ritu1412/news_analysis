# %%
from eventregistry import *
import json, os, sys
import pandas as pd
import numpy as np
from openai import OpenAI

# %%
api_key = os.getenv("NEWSAPI_API_KEY")
event_registry = EventRegistry(apiKey=api_key, allowUseOfArchive=False)
openai_client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# %%
search_query = "Joe Biden"
event_query = QueryEventsIter(keywords=search_query)
event_list =[]
for event in event_query.execQuery(event_registry, sortBy="Recent", maxItems=1):
    print(json.dumps(event, indent=4))
    #event_list.append(event)
# Out:
# {
#     "uri": "spa-3490090",
#     "concepts": [
#         {
#             "uri": "http://en.wikipedia.org/wiki/United_Kingdom",
#             "type": "loc",
#             "score": 100,
#             "label": {
#                 "eng": "United Kingdom"
#             },
#             "location": {
#                 "type": "country",
#                 "label": {
#                     "eng": "United Kingdom"
#                 }
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Prime_Minister_of_the_United_Kingdom",
#             "type": "wiki",
#             "score": 88,
#             "label": {
#                 "eng": "Prime Minister of the United Kingdom"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Labour_Party_(UK)",
#             "type": "org",
#             "score": 85,
#             "label": {
#                 "eng": "Labour Party (UK)"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Rishi_Sunak",
#             "type": "person",
#             "score": 65,
#             "label": {
#                 "eng": "Rishi Sunak"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Conservative_Party_(UK)",
#             "type": "org",
#             "score": 64,
#             "label": {
#                 "eng": "Conservative Party (UK)"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Conservatism",
#             "type": "wiki",
#             "score": 51,
#             "label": {
#                 "eng": "Conservatism"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Parliament",
#             "type": "wiki",
#             "score": 45,
#             "label": {
#                 "eng": "Parliament"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Prime_minister",
#             "type": "wiki",
#             "score": 43,
#             "label": {
#                 "eng": "Prime minister"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Keir_Starmer",
#             "type": "person",
#             "score": 34,
#             "label": {
#                 "eng": "Keir Starmer"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Inflation",
#             "type": "wiki",
#             "score": 33,
#             "label": {
#                 "eng": "Inflation"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/London",
#             "type": "loc",
#             "score": 33,
#             "label": {
#                 "eng": "London"
#             },
#             "location": {
#                 "type": "place",
#                 "label": {
#                     "eng": "London"
#                 },
#                 "country": {
#                     "type": "country",
#                     "label": {
#                         "eng": "United Kingdom"
#                     }
#                 }
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/10_Downing_Street",
#             "type": "wiki",
#             "score": 30,
#             "label": {
#                 "eng": "10 Downing Street"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Election",
#             "type": "wiki",
#             "score": 22,
#             "label": {
#                 "eng": "Election"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Downing_Street",
#             "type": "loc",
#             "score": 21,
#             "label": {
#                 "eng": "Downing Street"
#             },
#             "location": null
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Economy",
#             "type": "wiki",
#             "score": 20,
#             "label": {
#                 "eng": "Economy"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Tories_(British_political_party)",
#             "type": "org",
#             "score": 16,
#             "label": {
#                 "eng": "Tories (British political party)"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Boris_Johnson",
#             "type": "person",
#             "score": 16,
#             "label": {
#                 "eng": "Boris Johnson"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/House_of_Commons_of_the_United_Kingdom",
#             "type": "wiki",
#             "score": 15,
#             "label": {
#                 "eng": "House of Commons of the United Kingdom"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Opinion_poll",
#             "type": "wiki",
#             "score": 13,
#             "label": {
#                 "eng": "Opinion poll"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Cabinet_(government)",
#             "type": "wiki",
#             "score": 11,
#             "label": {
#                 "eng": "Cabinet (government)"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/World_War_II",
#             "type": "wiki",
#             "score": 10,
#             "label": {
#                 "eng": "World War II"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Rwanda",
#             "type": "loc",
#             "score": 10,
#             "label": {
#                 "eng": "Rwanda"
#             },
#             "location": {
#                 "type": "country",
#                 "label": {
#                     "eng": "Rwanda"
#                 }
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Parliament_of_the_United_Kingdom",
#             "type": "wiki",
#             "score": 9,
#             "label": {
#                 "eng": "Parliament of the United Kingdom"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Opposition_(politics)",
#             "type": "wiki",
#             "score": 9,
#             "label": {
#                 "eng": "Opposition (politics)"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Great_Britain",
#             "type": "loc",
#             "score": 9,
#             "label": {
#                 "eng": "Great Britain"
#             },
#             "location": null
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Liz_Truss",
#             "type": "person",
#             "score": 8,
#             "label": {
#                 "eng": "Liz Truss"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Charles_III_of_Spain",
#             "type": "person",
#             "score": 8,
#             "label": {
#                 "eng": "Charles III of Spain"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/David_Cameron",
#             "type": "person",
#             "score": 8,
#             "label": {
#                 "eng": "David Cameron"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/The_Guardian",
#             "type": "wiki",
#             "score": 8,
#             "label": {
#                 "eng": "The Guardian"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Deputy_(legislator)",
#             "type": "wiki",
#             "score": 7,
#             "label": {
#                 "eng": "Deputy (legislator)"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Social_democracy",
#             "type": "wiki",
#             "score": 7,
#             "label": {
#                 "eng": "Social democracy"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Sky_News",
#             "type": "org",
#             "score": 7,
#             "label": {
#                 "eng": "Sky News"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Electoral_district",
#             "type": "wiki",
#             "score": 7,
#             "label": {
#                 "eng": "Electoral district"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Politics",
#             "type": "wiki",
#             "score": 7,
#             "label": {
#                 "eng": "Politics"
#             }
#         },
#         {
#             "uri": "http://es.wikipedia.org/wiki/Pandemia_de_COVID-19",
#             "type": "wiki",
#             "score": 6,
#             "label": {
#                 "eng": "Pandemia de COVID-19"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Elizabeth_Truss",
#             "type": "person",
#             "score": 5,
#             "label": {
#                 "eng": "Elizabeth Truss"
#             }
#         },
#         {
#             "uri": "http://en.wikipedia.org/wiki/Government_of_the_United_Kingdom",
#             "type": "org",
#             "score": 5,
#             "label": {
#                 "eng": "Government of the United Kingdom"
#             }
#         }
#     ],
#     "eventDate": "2024-07-04",
#     "totalArticleCount": 460,
#     "title": {
#         "spa": "Sunak se la juega al adelantar las elecciones a julio con todos los elementos en contra",
#         "fra": "Royaume-Uni : Rishi Sunak convoque des \u00e9lections l\u00e9gislatives le 4 juillet",
#         "deu": "Premierminister Sunak k\u00fcndigt Neuwahlen in Gro\u00dfbritannien am 4. Juli an",
#         "zho": "\u82f1\u76f8\u8607\u7d0d\u514b\u63d0\u524d7/4\u5927\u9078 \u60c5\u52e2\u767c\u5c55\u4e00\u6b21\u770b",
#         "rus": "\u0412 \u0412\u0435\u043b\u0438\u043a\u043e\u0431\u0440\u0438\u0442\u0430\u043d\u0438\u0438 \u043f\u0440\u043e\u0432\u0435\u0434\u0443\u0442 \u0434\u043e\u0441\u0440\u043e\u0447\u043d\u044b\u0435 \u0432\u044b\u0431\u043e\u0440\u044b",
#         "por": "Primeiro-ministro do Reino Unido convoca elei\u00e7\u00f5es gerais para julho",
#         "ita": "Terremoto in gran bretagna - rishi sunak convoca le elezioni politiche per il 4 luglio: il primo...",
#         "ukr": "\u0421\u0443\u043d\u0430\u043a \u043f\u0440\u0438\u0437\u043d\u0430\u0447\u0438\u043b\u0438 \u0437\u0430\u0433\u0430\u043b\u044c\u043d\u0456 \u0432\u0438\u0431\u043e\u0440\u0438 \u0443 \u0412\u0435\u043b\u0438\u043a\u0456\u0439 \u0411\u0440\u0438\u0442\u0430\u043d\u0456\u0457",
#         "ita": "TERREMOTO IN GRAN BRETAGNA - RISHI SUNAK CONVOCA LE ELEZIONI POLITICHE PER IL PROSSIMO 4 LUGLIO: IL PRIMO MINISTRO HA DECISO DI AVVIARE LE PROCEDURE PER LO SCIOGLIMENTO DELLA CAMERA DEI COMUNI, DECIDENDO DI PORTARE I BRITANNICI AL VOTO CON SEI MESI DI ANTICIPO RISPETTO ALLA SCADENZA NATURALE DELLA LEGISLATURA - I SONDAGGI DANNO DA MESI L'OPPOSIZIONE LABURISTA DI KEIR STARMER IN NETTO VANTAGGIO SUI CONSERVATORI, AL POTERE DA 14 ANNI... - VIDEO -\n\n1. SUNAK NON ESCLUDE CONVOCAZIONE ELEZIONI IN ESTAT",
#         "ukr": "\u0421\u0443\u043d\u0430\u043a \u0437\u0430\u044f\u0432\u0438\u0432, \u0449\u043e \u043f\u0438\u0448\u0430\u0454\u0442\u044c\u0441\u044f \"\u0434\u043e\u0441\u044f\u0433\u043d\u0435\u043d\u043d\u044f\u043c\u0438 \u0441\u0432\u043e\u0433\u043e \u0443\u0440\u044f\u0434\u0443\", \u044f\u043a\u0438\u0439 \"\u0441\u0442\u0432\u043e\u0440\u0438\u0432 \u043a\u0440\u0430\u0449\u0435 \u043c\u0430\u0439\u0431\u0443\u0442\u043d\u0454 \u0434\u043b\u044f \u0434\u0456\u0442\u0435\u0439 \u0443 \u0412\u0435\u043b\u0438\u043a\u0456\u0439 \u0411\u0440\u0438\u0442\u0430\u043d\u0456\u0457\".\n\n\u041f\u0440\u0435\u043c'\u0454\u0440 \u0411\u0440\u0438\u0442\u0430\u043d\u0456\u0457 \u0420\u0456\u0448\u0456 \u0421\u0443\u043d\u0430\u043a \u043f\u0456\u0448\u043e\u0432 \u043d\u0430 \u0432\u0435\u043b\u0438\u0447\u0435\u0437\u043d\u0443 \u0430\u0432\u0430\u043d\u0442\u044e\u0440\u0443, \u043e\u0433\u043e\u043b\u043e\u0441\u0438\u0432\u0448\u0438 \u043f\u0440\u043e \u0432\u0438\u0431\u043e\u0440\u0438 4 \u043b\u0438\u043f\u043d\u044f, \u043f\u0456\u0434\u0448\u0442\u043e\u0432\u0445\u043d\u0443\u0432\u0448\u0438 \u0441\u0432\u043e\u0457\u0445 \u043a\u043e\u043d\u0441\u0435\u0440\u0432\u0430\u0442\u043e\u0440\u0456\u0432 \u0434\u043e \u0448\u0435\u0441\u0442\u0438\u0442\u0438\u0436\u043d\u0435\u0432\u043e\u0457 \u0432\u0438\u0431\u043e\u0440\u0447\u043e\u0457 \u043a\u0430\u043c\u043f\u0430\u043d\u0456\u0457, \u0432",
#         "eng": "A Sky News journalist was 'forcibly removed' from Rishi Sunak's campaign launch event on live television.\n\nPolitical correspondent Darren McCaffrey was removed from the campaign rally at London's ExCel Centre by two security guards in red hi-vis jackets.\n\nThe journalist and his camera crew were led down a corridor and bundled into an elevator, even though their bags were still in the room where the event was being held.\n\nMr McCaffrey remained calm during the ordeal and said: 'I am being forcibly ",
#         "tur": "\u0130ngiltere Ba\u015fbakan\u0131 Rishi Sunak, erken se\u00e7im a\u00e7\u0131klamas\u0131nda bulundu.\n\nBa\u015fbakan Sunak, erken se\u00e7imin 4 Temmuz'da yap\u0131laca\u011f\u0131n\u0131 a\u00e7\u0131klad\u0131.\n\n\u0130ngiltere'de son olarak Aral\u0131k 2019'da se\u00e7im yap\u0131lm\u0131\u015ft\u0131. Erken se\u00e7im karar\u0131 a\u00e7\u0131klanmasayd\u0131 \u0130ngiltere se\u00e7imi Aral\u0131k 2024'te yap\u0131lacakt\u0131.\n\nUzun zamand\u0131r se\u00e7im tarihini a\u00e7\u0131klama bask\u0131s\u0131 alt\u0131nda olan Sunak, be\u015f y\u0131ll\u0131k d\u00f6nemin dolaca\u011f\u0131 \u015fekilde y\u0131l sonunu i\u015faret ediyordu. Ana muhalefet \u0130\u015f\u00e7i Partisi lideri Keir Starmer,",
#         "hrv": "BRITANSKI premijer Rishi Sunak danas je objavio da \u0107e se parlamentarni izbori odr\u017eati 4. srpnja, ranije nego se o\u010dekivalo, a nakon 14 godina vladavine konzervativaca gotovo je pa izvjesno da \u0107e pobjedu odnijeti Laburisti\u010dka stranka.\n\nPrekinuv\u0161i vi\u0161emjese\u010dna naga\u0111anja kada \u0107e raspisati izbore, 44-godi\u0161nji Sunak je pred uredom u Downing Streetu najavio odr\u017eavanje izbora po\u010detkom srpnja, \u0161to bi se moglo pokazati rizi\u010dnom strategijom s obzirom na to da njegova stranka u anketama zaosta",
#         "cat": "MADRID, 22 May. (EUROPA PRESS) -\n\nEl primer ministre brit\u00e0nic, Rishi Sunak, ha anunciat a les portes del n\u00famero 10 de Downing Street que les eleccions generals del Regne Unit se celebraran el pr\u00f2xim 4 de juliol, mig any abans de la data prevista.\n\n\"Ara \u00e9s el moment que el Regne Unit trie el seu futur\", ha assenyalat el primer ministre brit\u00e0nic, que ha repassat alguns assoliments recents \"durant el moment m\u00e9s complex des de la Segona Guerra Mundial\" i ha destacat, entre d'altres, la millora "
#     },
#     "location": {
#         "type": "place",
#         "label": {
#             "eng": "London"
#         },
#         "country": {
#             "type": "country",
#             "label": {
#                 "eng": "United Kingdom"
#             }
#         }
#     },
#     "categories": [
#         {
#             "uri": "dmoz/Society/Activism/Media",
#             "label": "dmoz/Society/Activism/Media",
#             "wgt": 85
#         },
#         {
#             "uri": "news/Politics",
#             "label": "news/Politics",
#             "wgt": 80
#         },
#         {
#             "uri": "news/Business",
#             "label": "news/Business",
#             "wgt": 58
#         }
#     ],
#     "articleCounts": {
#         "spa": 132,
#         "fra": 66,
#         "deu": 45,
#         "zho": 40,
#         "rus": 54,
#         "por": 41,
#         "ita": 36,
#         "ukr": 15,
#         "eng": 10,
#         "tur": 7,
#         "hrv": 7,
#         "cat": 7
#     },
#     "sentiment": 0.1137254901960785,
#     "wgt": 457747200,
#     "relevance": 24
# }

# %%
event_uri = event["uri"]
lang = "eng"
q = QueryEventArticlesIter(eventUri=event_uri, lang=lang)
filename = "../data/processed/" + lang + "_" + event_uri + ".json"
if os.path.exists(filename):
    os.remove(filename)
articles = []
for article in q.execQuery(
    event_registry,
    sortBy="date",
    maxItems=10,
    returnInfo=ReturnInfo(sourceInfo=SourceInfoFlags(location=True),),
    ):
    articles.append(article)

with open(filename, "w") as f:
    json.dump(articles, f, ensure_ascii=False, indent=4)

# %%
lang = "eng"
q = QueryEventArticlesIter(eventUri=event_uri, lang=lang)
filename = "../data/processed/" + lang + "_" + event_uri + ".json"
if os.path.exists(filename):
    os.remove(filename)
articles = []
for article in q.execQuery(
    event_registry,
    sortBy="date",
    maxItems=10,
    returnInfo=ReturnInfo(sourceInfo=SourceInfoFlags(location=True),),
    ):
    articles.append(article)

with open(filename, "w") as f:
    json.dump(articles, f, ensure_ascii=False, indent=4)

# %%
def openai_distinctive_events_list(
    article,
    openai_client,
    model="gpt-4o",
):

    prompt_complete = (
        f"You are an expert at summarizing the news. \
            Read the following news article and translate it into English if necessary. \
                 Create a list of distinctive events described in the article, arranged in chronological order. The first event listed should be the earliest event mentioned in the article, followed by the subsequent events in the order they occurred: "
        + article["body"]
    )
    model = model
    messages = [{"role": "user", "content": prompt_complete}]
    try:
        response = openai_client.chat.completions.create(
            model=model, messages=messages, temperature=0
        )

        content = response.choices[0].message.content
        return content
    except Exception as e:  # if the model fails to return a response
        print(f"Error: {e}")
        return "Sorry, error from GPT."

# %%
src_filename = "../data/processed/" + lang + "_" + event_uri + ".json"
with open(src_filename, "r") as f:
    data = f.read()
    des_articles = []
    src_articles = json.loads(data)
    for src_art in src_articles:
        src_art["distinctive_events"] = openai_distinctive_events_list(
            src_art, openai_client, model="gpt-4o"
        )

        des_articles.append(src_art)

des_filename = src_filename + "_distinctive_events.json"
if os.path.exists(des_filename):
    os.remove(des_filename)
with open(des_filename, "w") as f:
    json.dump(des_articles, f, indent=4)

# %%
lang = "zho"
src_filename = "../data/processed/" + lang + "_" + event_uri + ".json"
with open(src_filename, "r") as f:
    data = f.read()
    des_articles = []
    src_articles = json.loads(data)
    for src_art in src_articles:
        src_art["distinctive_events"] = openai_distinctive_events_list(
            src_art, openai_client, model="gpt-4o"
        )

        des_articles.append(src_art)

des_filename = src_filename + "_distinctive_events.json"
if os.path.exists(des_filename):
    os.remove(des_filename)
with open(des_filename, "w") as f:
    json.dump(des_articles, f, indent=4)

# %%
lang = "zho"
src_filename = "../data/processed/" + lang + "_" + event_uri + ".json"
with open(src_filename, "r") as f:
    data = f.read()
    des_articles = []
    src_articles = json.loads(data)
    for src_art in src_articles:
        src_art["distinctive_events"] = openai_distinctive_events_list(
            src_art, openai_client, model="gpt-4o"
        )

        des_articles.append(src_art)

des_filename = src_filename + "_distinctive_events.json"
if os.path.exists(des_filename):
    os.remove(des_filename)
with open(des_filename, "w") as f:
    json.dump(des_articles, f, indent=4)

# %%
lang = "hin"
src_filename = "../data/processed/" + lang + "_" + "hin-359877" + ".json"
with open(src_filename, "r") as f:
    data = f.read()
    des_articles = []
    src_articles = json.loads(data)
    for src_art in src_articles:
        src_art["distinctive_events"] = openai_distinctive_events_list(
            src_art, openai_client, model="gpt-4o"
        )

        des_articles.append(src_art)

des_filename = src_filename + "_distinctive_events.json"
if os.path.exists(des_filename):
    os.remove(des_filename)
with open(des_filename, "w") as f:
    json.dump(des_articles, f, indent=4)
